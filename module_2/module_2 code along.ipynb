# %%
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error

# %%
import mlflow

mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("ny-taxi-experiment")
# Out:
# 2023/05/27 18:06:57 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2023/05/27 18:06:57 INFO mlflow.store.db.utils: Updating database tables
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# INFO  [alembic.runtime.migration] Running upgrade  -> 451aebb31d03, add metric step
# INFO  [alembic.runtime.migration] Running upgrade 451aebb31d03 -> 90e64c465722, migrate user column to tags
# INFO  [alembic.runtime.migration] Running upgrade 90e64c465722 -> 181f10493468, allow nulls for metric values
# INFO  [alembic.runtime.migration] Running upgrade 181f10493468 -> df50e92ffc5e, Add Experiment Tags Table
# INFO  [alembic.runtime.migration] Running upgrade df50e92ffc5e -> 7ac759974ad8, Update run tags with larger limit
# INFO  [alembic.runtime.migration] Running upgrade 7ac759974ad8 -> 89d4b8295536, create latest metrics table
# INFO  [89d4b8295536_create_latest_metrics_table_py] Migration complete!
# INFO  [alembic.runtime.migration] Running upgrade 89d4b8295536 -> 2b4d017a5e9b, add model registry tables to db
# INFO  [2b4d017a5e9b_add_model_registry_tables_to_db_py] Adding registered_models and model_versions tables to database.
# INFO  [2b4d017a5e9b_add_model_registry_tables_to_db_py] Migration complete!
# INFO  [alembic.runtime.migration] Running upgrade 2b4d017a5e9b -> cfd24bdc0731, Update run status constraint with killed
# INFO  [alembic.runtime.migration] Running upgrade cfd24bdc0731 -> 0a8213491aaa, drop_duplicate_killed_constraint
# INFO  [alembic.runtime.migration] Running upgrade 0a8213491aaa -> 728d730b5ebd, add registered model tags table
# INFO  [alembic.runtime.migration] Running upgrade 728d730b5ebd -> 27a6a02d2cf1, add model version tags table
# INFO  [alembic.runtime.migration] Running upgrade 27a6a02d2cf1 -> 84291f40a231, add run_link to model_version
# INFO  [alembic.runtime.migration] Running upgrade 84291f40a231 -> a8c4a736bde6, allow nulls for run_id
# INFO  [alembic.runtime.migration] Running upgrade a8c4a736bde6 -> 39d1c3be5f05, add_is_nan_constraint_for_metrics_tables_if_necessary
# INFO  [alembic.runtime.migration] Running upgrade 39d1c3be5f05 -> c48cb773bb87, reset_default_value_for_is_nan_in_metrics_table_for_mysql
# INFO  [alembic.runtime.migration] Running upgrade c48cb773bb87 -> bd07f7e963c5, create index on run_uuid
# INFO  [alembic.runtime.migration] Running upgrade bd07f7e963c5 -> 0c779009ac13, add deleted_time field to runs table
# INFO  [alembic.runtime.migration] Running upgrade 0c779009ac13 -> cc1f77228345, change param value length to 500
# INFO  [alembic.runtime.migration] Running upgrade cc1f77228345 -> 97727af70f4d, Add creation_time and last_update_time to experiments table
# INFO  [alembic.runtime.migration] Running upgrade 97727af70f4d -> 3500859a5d39, Add Model Aliases table
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# 2023/05/27 18:06:58 INFO mlflow.tracking.fluent: Experiment with name 'ny-taxi-experiment' does not exist. Creating a new experiment.
# <Experiment: artifact_location='/home/incogrev/Documents/mlops-zoomcamp/module_2/mlruns/1', creation_time=1685236018062, experiment_id='1', last_update_time=1685236018062, lifecycle_stage='active', name='ny-taxi-experiment', tags={}>

# %%
def read_dataframe(filename):
    df = pd.read_parquet(filename)

    df['duration'] = df['tpep_dropoff_datetime'] - df['tpep_pickup_datetime']

    df['duration'] = df.duration.apply(lambda td: td.total_seconds()/60 )
    df = df[((df.duration >= 1) &  (df.duration <=60))]

    categorical = ['PULocationID', 'DOLocationID']
    numerical = ['trip_distance']

    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
df_train = read_dataframe('./data/yellow_tripdata_2022-01.parquet')
df_val = read_dataframe('./data/yellow_tripdata_2022-02.parquet')

# %%
len(df_train), len(df_val)
# Out:
# (2421440, 2918187)

# %%
train_dicts = df[categorical + numerical].to_dict(orient='records')
dv = DictVectorizer()
X_train = dv.fit_transform(train_dicts)

target = 'duration'
y_train = df[target].values

lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_train)

mean_squared_error(y_train, y_pred, squared=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 train_dicts = df[categorical + numerical].to_dict(orient='records')
#       2 dv = DictVectorizer()
#       3 X_train = dv.fit_transform(train_dicts)
#
# NameError: name 'df' is not defined

# %%
categorical = ['PULocationID', 'DOLocationID']
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)


val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
target = 'duration'
y_train = df_train[target].values

y_val = df_val[target].values

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

mean_squared_error(y_val, y_pred, squared=False)
# Out:
# 7.7954986956554695

# %%
y_pred = lr.predict(X_train)

mean_squared_error(y_train, y_pred, squared=False)
# Out:
# 7.001496179430534

# %%
with mlflow.start_run():

    mlflow.set_tag("developer", "prerit")

    mlflow.log_param("train-data-path", "./data/yellow_tripdata_2022-01.parquet")
    mlflow.log_param("valid-data-path", "./data/yellow_tripdata_2022-02.parquet")
 
    alpha = 0.01
    mlflow.log_param("alpha", alpha)

    lr = Lasso(alpha)
    lr.fit(X_train, y_train)

    y_pred = lr.predict(X_val)

    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)

# %%
import xgboost as xgb

from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
def objective(params):

    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, "validation")],
            early_stopping_rounds=50
        )

        y_pred = booster.predict(valid)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)

    return {'loss': rmse, 'status': STATUS_OK}

# %%
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42
}


best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
)
# Out:
# [20:03:23] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:6.25098
# [1]	validation-rmse:5.18405
# [2]	validation-rmse:5.04454
# [3]	validation-rmse:5.02493
# [4]	validation-rmse:4.99701
# [5]	validation-rmse:4.98942
# [6]	validation-rmse:4.98104
# [7]	validation-rmse:4.96913
# [8]	validation-rmse:4.96529
# [9]	validation-rmse:4.95461
# [10]	validation-rmse:4.95181
# [11]	validation-rmse:4.94885
# [12]	validation-rmse:4.94533
# [13]	validation-rmse:4.94494
# [14]	validation-rmse:4.94320
# [15]	validation-rmse:4.94074
# [16]	validation-rmse:4.93808
# [17]	validation-rmse:4.93725
# [18]	validation-rmse:4.93335
# [19]	validation-rmse:4.93390
# [20]	validation-rmse:4.93302
# [21]	validation-rmse:4.92346
# [22]	validation-rmse:4.91690
# [23]	validation-rmse:4.91651
# [24]	validation-rmse:4.91724
# [25]	validation-rmse:4.91628
# [26]	validation-rmse:4.91679
# [27]	validation-rmse:4.91605
# [28]	validation-rmse:4.91471
# [29]	validation-rmse:4.91311
# [30]	validation-rmse:4.91408
# [31]	validation-rmse:4.91349
# [32]	validation-rmse:4.91373
# [33]	validation-rmse:4.91406
# [34]	validation-rmse:4.91284
# [35]	validation-rmse:4.91283
# [36]	validation-rmse:4.91325
# [37]	validation-rmse:4.91330
# [38]	validation-rmse:4.91506
# [39]	validation-rmse:4.91501
# [40]	validation-rmse:4.91510
# [41]	validation-rmse:4.91494
# [42]	validation-rmse:4.91604
# [43]	validation-rmse:4.91619
# [44]	validation-rmse:4.91683
# [45]	validation-rmse:4.91697
# [46]	validation-rmse:4.91757
# [47]	validation-rmse:4.91850
# [48]	validation-rmse:4.91941
# [49]	validation-rmse:4.92009
# [50]	validation-rmse:4.92046
# [51]	validation-rmse:4.92067
# [52]	validation-rmse:4.92116
# [53]	validation-rmse:4.92162
# [54]	validation-rmse:4.92093
# [55]	validation-rmse:4.92236
# [56]	validation-rmse:4.92302
# [57]	validation-rmse:4.92323
# [58]	validation-rmse:4.92402
# [59]	validation-rmse:4.92487
# [60]	validation-rmse:4.92509
# [61]	validation-rmse:4.92626
# [62]	validation-rmse:4.92657
# [63]	validation-rmse:4.92695
# [64]	validation-rmse:4.92994
# [65]	validation-rmse:4.93069
# [66]	validation-rmse:4.93107
# [67]	validation-rmse:4.93331
# [68]	validation-rmse:4.93401
# [69]	validation-rmse:4.93556
# [70]	validation-rmse:4.93555
# [71]	validation-rmse:4.93700
# [72]	validation-rmse:4.93864
# [73]	validation-rmse:4.94010
# [74]	validation-rmse:4.94169
# [75]	validation-rmse:4.94242
# [76]	validation-rmse:4.94336
# [77]	validation-rmse:4.94328
# [78]	validation-rmse:4.94560
# [79]	validation-rmse:4.94595
# [80]	validation-rmse:4.94629
# [81]	validation-rmse:4.94768
# [82]	validation-rmse:4.94796
# [83]	validation-rmse:4.95006
# [84]	validation-rmse:4.95082
# [20:06:31] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:12.63988
# [1]	validation-rmse:10.02227
# [2]	validation-rmse:8.24664
# [3]	validation-rmse:7.06941
# [4]	validation-rmse:6.30442
# [5]	validation-rmse:5.81511
# [6]	validation-rmse:5.50204
# [7]	validation-rmse:5.30125
# [8]	validation-rmse:5.16938
# [9]	validation-rmse:5.08080
# [10]	validation-rmse:5.02160
# [11]	validation-rmse:4.97762
# [12]	validation-rmse:4.94838
# [13]	validation-rmse:4.92874
# [14]	validation-rmse:4.91375
# [15]	validation-rmse:4.90224
# [16]	validation-rmse:4.89522
# [17]	validation-rmse:4.88937
# [18]	validation-rmse:4.88625
# [19]	validation-rmse:4.88266
# [20]	validation-rmse:4.88097
# [21]	validation-rmse:4.87937
# [22]	validation-rmse:4.87791
# [23]	validation-rmse:4.87603
# [24]	validation-rmse:4.87543
# [25]	validation-rmse:4.87480
# [26]	validation-rmse:4.87437
# [27]	validation-rmse:4.87309
# [28]	validation-rmse:4.87242
# [29]	validation-rmse:4.87140
# [30]	validation-rmse:4.87090
# [31]	validation-rmse:4.86997
# [32]	validation-rmse:4.86775
# [33]	validation-rmse:4.86793
# [34]	validation-rmse:4.86781
# [35]	validation-rmse:4.86797
# [36]	validation-rmse:4.86669
# [37]	validation-rmse:4.86673
# [38]	validation-rmse:4.86605
# [39]	validation-rmse:4.86632
# [40]	validation-rmse:4.86434
# [41]	validation-rmse:4.86398
# [42]	validation-rmse:4.86395
# [43]	validation-rmse:4.86431
# [44]	validation-rmse:4.86441
# [45]	validation-rmse:4.86410
# [46]	validation-rmse:4.86451
# [47]	validation-rmse:4.86488
# [48]	validation-rmse:4.86423
# [49]	validation-rmse:4.86262
# [50]	validation-rmse:4.86327
# [51]	validation-rmse:4.86351
# [52]	validation-rmse:4.86409
# [53]	validation-rmse:4.86416
# [54]	validation-rmse:4.86465
# [55]	validation-rmse:4.86525
# [56]	validation-rmse:4.86570
# [57]	validation-rmse:4.86552
# [58]	validation-rmse:4.86576
# [59]	validation-rmse:4.86613
# [60]	validation-rmse:4.86685
# [61]	validation-rmse:4.86731
# [62]	validation-rmse:4.86840
# [63]	validation-rmse:4.86829
# [64]	validation-rmse:4.86864
# [65]	validation-rmse:4.86817
# [66]	validation-rmse:4.86886
# [67]	validation-rmse:4.86936
# [68]	validation-rmse:4.87001
# [69]	validation-rmse:4.87012
# [70]	validation-rmse:4.87061
# [71]	validation-rmse:4.87097
# [72]	validation-rmse:4.87145
# [73]	validation-rmse:4.87231
# [74]	validation-rmse:4.87284
# [75]	validation-rmse:4.87345
# [76]	validation-rmse:4.87317
# [77]	validation-rmse:4.87355
# [78]	validation-rmse:4.87469
# [79]	validation-rmse:4.87506
# [80]	validation-rmse:4.87530
# [81]	validation-rmse:4.87606
# [82]	validation-rmse:4.87652
# [83]	validation-rmse:4.87687
# [84]	validation-rmse:4.87801
# [85]	validation-rmse:4.87846
# [86]	validation-rmse:4.87869
# [87]	validation-rmse:4.87928
# [88]	validation-rmse:4.88003
# [89]	validation-rmse:4.88032
# [90]	validation-rmse:4.88130
# [91]	validation-rmse:4.88192
# [92]	validation-rmse:4.88261
# [93]	validation-rmse:4.88300
# [94]	validation-rmse:4.88348
# [95]	validation-rmse:4.88384
# [96]	validation-rmse:4.88500
# [97]	validation-rmse:4.88576
# [98]	validation-rmse:4.88646
# [99]	validation-rmse:4.88657
# [20:13:13] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:13.86008
# [1]	validation-rmse:11.82808
# [2]	validation-rmse:10.22808
# [3]	validation-rmse:8.98031
# [4]	validation-rmse:8.01544
# [5]	validation-rmse:7.27605
# [6]	validation-rmse:6.71410
# [7]	validation-rmse:6.29146
# [8]	validation-rmse:5.97311
# [9]	validation-rmse:5.73236
# [10]	validation-rmse:5.55141
# [11]	validation-rmse:5.41522
# [12]	validation-rmse:5.31084
# [13]	validation-rmse:5.22959
# [14]	validation-rmse:5.16867
# [15]	validation-rmse:5.11966
# [16]	validation-rmse:5.08166
# [17]	validation-rmse:5.05058
# [18]	validation-rmse:5.02496
# [19]	validation-rmse:5.00588
# [20]	validation-rmse:4.98910
# [21]	validation-rmse:4.97646
# [22]	validation-rmse:4.96681
# [23]	validation-rmse:4.95720
# [24]	validation-rmse:4.95197
# [25]	validation-rmse:4.94535
# [26]	validation-rmse:4.94169
# [27]	validation-rmse:4.93730
# [28]	validation-rmse:4.93266
# [29]	validation-rmse:4.92969
# [30]	validation-rmse:4.92639
# [31]	validation-rmse:4.92446
# [32]	validation-rmse:4.92289
# [33]	validation-rmse:4.92151
# [34]	validation-rmse:4.91687
# [35]	validation-rmse:4.91396
# [36]	validation-rmse:4.91126
# [37]	validation-rmse:4.90951
# [38]	validation-rmse:4.90871
# [39]	validation-rmse:4.90701
# [40]	validation-rmse:4.90387
# [41]	validation-rmse:4.90321
# [42]	validation-rmse:4.90263
# [43]	validation-rmse:4.90186
# [44]	validation-rmse:4.89924
# [45]	validation-rmse:4.89742
# [46]	validation-rmse:4.89689
# [47]	validation-rmse:4.89637
# [48]	validation-rmse:4.89460
# [49]	validation-rmse:4.89384
# [50]	validation-rmse:4.89180
# [51]	validation-rmse:4.88886
# [52]	validation-rmse:4.88846
# [53]	validation-rmse:4.88804
# [54]	validation-rmse:4.88584
# [55]	validation-rmse:4.88530
# [56]	validation-rmse:4.88375
# [57]	validation-rmse:4.88222
# [58]	validation-rmse:4.88172
# [59]	validation-rmse:4.88151
# [60]	validation-rmse:4.87995
# [61]	validation-rmse:4.87883
# [62]	validation-rmse:4.87774
# [63]	validation-rmse:4.87743
# [64]	validation-rmse:4.87545
# [65]	validation-rmse:4.87430
# [66]	validation-rmse:4.87365
# [67]	validation-rmse:4.87335
# [68]	validation-rmse:4.87265
# [69]	validation-rmse:4.87145
# [70]	validation-rmse:4.86889
# [71]	validation-rmse:4.86798
# [72]	validation-rmse:4.86726
# [73]	validation-rmse:4.86703
# [74]	validation-rmse:4.86632
# [75]	validation-rmse:4.86507
# [76]	validation-rmse:4.86473
# [77]	validation-rmse:4.86432
# [78]	validation-rmse:4.86193
# [79]	validation-rmse:4.86029
# [80]	validation-rmse:4.85975
# [81]	validation-rmse:4.85938
# [82]	validation-rmse:4.85819
# [83]	validation-rmse:4.85706
# [84]	validation-rmse:4.85618
# [85]	validation-rmse:4.85607
# [86]	validation-rmse:4.85492
# [87]	validation-rmse:4.85468
# [88]	validation-rmse:4.85393
# [89]	validation-rmse:4.85376
# [90]	validation-rmse:4.85329
# [91]	validation-rmse:4.85313
# [92]	validation-rmse:4.85203
# [93]	validation-rmse:4.85147
# [94]	validation-rmse:4.85107
# [95]	validation-rmse:4.85018
# [96]	validation-rmse:4.84941
# [97]	validation-rmse:4.84868
# [98]	validation-rmse:4.84859
# [99]	validation-rmse:4.84716
# [100]	validation-rmse:4.84589
# [101]	validation-rmse:4.84461
# [102]	validation-rmse:4.84445
# [103]	validation-rmse:4.84432
# [104]	validation-rmse:4.84403
# [105]	validation-rmse:4.84392
# [106]	validation-rmse:4.84348
# [107]	validation-rmse:4.84344
# [108]	validation-rmse:4.84336
# [109]	validation-rmse:4.84291
# [110]	validation-rmse:4.84267
# [111]	validation-rmse:4.84237
# [112]	validation-rmse:4.84181
# [113]	validation-rmse:4.84135
# [114]	validation-rmse:4.84109
# [115]	validation-rmse:4.84079
# [116]	validation-rmse:4.84057
# [117]	validation-rmse:4.83977
# [118]	validation-rmse:4.83858
# [119]	validation-rmse:4.83755
# [120]	validation-rmse:4.83697
# [121]	validation-rmse:4.83687
# [122]	validation-rmse:4.83612
# [123]	validation-rmse:4.83570
# [124]	validation-rmse:4.83564
# [125]	validation-rmse:4.83549
# [126]	validation-rmse:4.83547
# [127]	validation-rmse:4.83522
# [128]	validation-rmse:4.83508
# [129]	validation-rmse:4.83479
# [130]	validation-rmse:4.83431
# [131]	validation-rmse:4.83380
# [132]	validation-rmse:4.83362
# [133]	validation-rmse:4.83343
# [134]	validation-rmse:4.83315
# [135]	validation-rmse:4.83302
# [136]	validation-rmse:4.83264
# [137]	validation-rmse:4.83200
# [138]	validation-rmse:4.83091
# [139]	validation-rmse:4.83005
# [140]	validation-rmse:4.82885
# [141]	validation-rmse:4.82848
# [142]	validation-rmse:4.82766
# [143]	validation-rmse:4.82616
# [144]	validation-rmse:4.82614
# [145]	validation-rmse:4.82552
# [146]	validation-rmse:4.82543
# [147]	validation-rmse:4.82541
# [148]	validation-rmse:4.82536
# [149]	validation-rmse:4.82535
# [150]	validation-rmse:4.82464
# [151]	validation-rmse:4.82468
# [152]	validation-rmse:4.82457
# [153]	validation-rmse:4.82422
# [154]	validation-rmse:4.82408
# [155]	validation-rmse:4.82368
# [156]	validation-rmse:4.82364
# [157]	validation-rmse:4.82364
# [158]	validation-rmse:4.82347
# [159]	validation-rmse:4.82334
# [160]	validation-rmse:4.82333
# [161]	validation-rmse:4.82264
# [162]	validation-rmse:4.82255
# [163]	validation-rmse:4.82205
# [164]	validation-rmse:4.82177
# [165]	validation-rmse:4.82157
# [166]	validation-rmse:4.82103
# [167]	validation-rmse:4.82073
# [168]	validation-rmse:4.82045
# [169]	validation-rmse:4.82019
# [170]	validation-rmse:4.82009
# [171]	validation-rmse:4.81965
# [172]	validation-rmse:4.81944
# [173]	validation-rmse:4.81918
# [174]	validation-rmse:4.81899
# [175]	validation-rmse:4.81864
# [176]	validation-rmse:4.81873
# [177]	validation-rmse:4.81862
# [178]	validation-rmse:4.81821
# [179]	validation-rmse:4.81805
# [180]	validation-rmse:4.81793
# [181]	validation-rmse:4.81789
# [182]	validation-rmse:4.81705
# [183]	validation-rmse:4.81701
# [184]	validation-rmse:4.81598
# [185]	validation-rmse:4.81581
# [186]	validation-rmse:4.81581
# [187]	validation-rmse:4.81561
# [188]	validation-rmse:4.81547
# [189]	validation-rmse:4.81532
# [190]	validation-rmse:4.81477
# [191]	validation-rmse:4.81476
# [192]	validation-rmse:4.81466
# [193]	validation-rmse:4.81413
# [194]	validation-rmse:4.81410
# [195]	validation-rmse:4.81383
# [196]	validation-rmse:4.81374
# [197]	validation-rmse:4.81367
# [198]	validation-rmse:4.81367
# [199]	validation-rmse:4.81329
# [200]	validation-rmse:4.81320
# [201]	validation-rmse:4.81314
# [202]	validation-rmse:4.81260
# [203]	validation-rmse:4.81237
# [204]	validation-rmse:4.81234
# [205]	validation-rmse:4.81205
# [206]	validation-rmse:4.81204
# [207]	validation-rmse:4.81182
# [208]	validation-rmse:4.81175
# [209]	validation-rmse:4.81176
# [210]	validation-rmse:4.81172
# [211]	validation-rmse:4.81174
# [212]	validation-rmse:4.81149
# [213]	validation-rmse:4.81146
# [214]	validation-rmse:4.81126
# [215]	validation-rmse:4.81108
# [216]	validation-rmse:4.81093
# [217]	validation-rmse:4.81035
# [218]	validation-rmse:4.81029
# [219]	validation-rmse:4.81034
# [220]	validation-rmse:4.81019
# [221]	validation-rmse:4.81007
# [222]	validation-rmse:4.81007
# [223]	validation-rmse:4.81000
# [224]	validation-rmse:4.80996
# [225]	validation-rmse:4.80954
# [226]	validation-rmse:4.80956
# [227]	validation-rmse:4.80956
# [228]	validation-rmse:4.80940
# [229]	validation-rmse:4.80939
# [230]	validation-rmse:4.80941
# [231]	validation-rmse:4.80948
# [232]	validation-rmse:4.80943
# [233]	validation-rmse:4.80938
# [234]	validation-rmse:4.80922
# [235]	validation-rmse:4.80894
# [236]	validation-rmse:4.80876
# [237]	validation-rmse:4.80873
# [238]	validation-rmse:4.80846
# [239]	validation-rmse:4.80852
# [240]	validation-rmse:4.80848
# [241]	validation-rmse:4.80851
# [242]	validation-rmse:4.80817
# [243]	validation-rmse:4.80788
# [244]	validation-rmse:4.80750
# [245]	validation-rmse:4.80717
# [246]	validation-rmse:4.80714
# [247]	validation-rmse:4.80695
# [248]	validation-rmse:4.80691
# [249]	validation-rmse:4.80692
# [250]	validation-rmse:4.80677
# [251]	validation-rmse:4.80673
# [252]	validation-rmse:4.80666
# [253]	validation-rmse:4.80555
# [254]	validation-rmse:4.80547
# [255]	validation-rmse:4.80546
# [256]	validation-rmse:4.80540
# [257]	validation-rmse:4.80539
# [258]	validation-rmse:4.80517
# [259]	validation-rmse:4.80502
# [260]	validation-rmse:4.80458
# [261]	validation-rmse:4.80463
# [262]	validation-rmse:4.80458
# [263]	validation-rmse:4.80454
# [264]	validation-rmse:4.80458
# [265]	validation-rmse:4.80460
# [266]	validation-rmse:4.80461
# [267]	validation-rmse:4.80425
# [268]	validation-rmse:4.80427
# [269]	validation-rmse:4.80376
# [270]	validation-rmse:4.80349
# [271]	validation-rmse:4.80343
# [272]	validation-rmse:4.80352
# [273]	validation-rmse:4.80355
# [274]	validation-rmse:4.80341
# [275]	validation-rmse:4.80341
# [276]	validation-rmse:4.80344
# [277]	validation-rmse:4.80345
# [278]	validation-rmse:4.80349
# [279]	validation-rmse:4.80345
# [280]	validation-rmse:4.80331
# [281]	validation-rmse:4.80311
# [282]	validation-rmse:4.80305
# [283]	validation-rmse:4.80309
# [284]	validation-rmse:4.80310
# [285]	validation-rmse:4.80286
# [286]	validation-rmse:4.80288
# [287]	validation-rmse:4.80280
# [288]	validation-rmse:4.80279
# [289]	validation-rmse:4.80285
# [290]	validation-rmse:4.80209
# [291]	validation-rmse:4.80200
# [292]	validation-rmse:4.80190
# [293]	validation-rmse:4.80195
# [294]	validation-rmse:4.80198
# [295]	validation-rmse:4.80198
# [296]	validation-rmse:4.80198
# [297]	validation-rmse:4.80199
# [298]	validation-rmse:4.80202
# [299]	validation-rmse:4.80205
# [300]	validation-rmse:4.80205
# [301]	validation-rmse:4.80206
# [302]	validation-rmse:4.80175
# [303]	validation-rmse:4.80173
# [304]	validation-rmse:4.80115
# [305]	validation-rmse:4.80118
# [306]	validation-rmse:4.80124
# [307]	validation-rmse:4.80104
# [308]	validation-rmse:4.80108
# [309]	validation-rmse:4.80107
# [310]	validation-rmse:4.80107
# [311]	validation-rmse:4.80105
# [312]	validation-rmse:4.80103
# [313]	validation-rmse:4.80089
# [314]	validation-rmse:4.80083
# [315]	validation-rmse:4.80036
# [316]	validation-rmse:4.80040
# [317]	validation-rmse:4.80038
# [318]	validation-rmse:4.80038
# [319]	validation-rmse:4.80038
# [320]	validation-rmse:4.80040
# [321]	validation-rmse:4.80046
# [322]	validation-rmse:4.80037
# [323]	validation-rmse:4.80039
# [324]	validation-rmse:4.80029
# [325]	validation-rmse:4.80009
# [326]	validation-rmse:4.80020
# [327]	validation-rmse:4.80016
# [328]	validation-rmse:4.80017
# [329]	validation-rmse:4.80022
# [330]	validation-rmse:4.80020
# [331]	validation-rmse:4.80010
# [332]	validation-rmse:4.80006
# [333]	validation-rmse:4.80006
# [334]	validation-rmse:4.80007
# [335]	validation-rmse:4.80006
# [336]	validation-rmse:4.80008
# [337]	validation-rmse:4.79997
# [338]	validation-rmse:4.79989
# [339]	validation-rmse:4.79990
# [340]	validation-rmse:4.79983
# [341]	validation-rmse:4.79988
# [342]	validation-rmse:4.79988
# [343]	validation-rmse:4.79989
# [344]	validation-rmse:4.79982
# [345]	validation-rmse:4.79987
# [346]	validation-rmse:4.79993
# [347]	validation-rmse:4.79989
# [348]	validation-rmse:4.79992
# [349]	validation-rmse:4.79989
# [350]	validation-rmse:4.79996
# [351]	validation-rmse:4.79989
# [352]	validation-rmse:4.79993
# [353]	validation-rmse:4.79990
# [354]	validation-rmse:4.79992
# [355]	validation-rmse:4.79984
# [356]	validation-rmse:4.79986
# [357]	validation-rmse:4.79987
# [358]	validation-rmse:4.79982
# [359]	validation-rmse:4.79981
# [360]	validation-rmse:4.79982
# [361]	validation-rmse:4.79983
# [362]	validation-rmse:4.79983
# [363]	validation-rmse:4.79983
# [364]	validation-rmse:4.79966
# [365]	validation-rmse:4.79965
# [366]	validation-rmse:4.79965
# [367]	validation-rmse:4.79961
# [368]	validation-rmse:4.79959
# [369]	validation-rmse:4.79961
# [370]	validation-rmse:4.79956
# [371]	validation-rmse:4.79957
# [372]	validation-rmse:4.79958
# [373]	validation-rmse:4.79959
# [374]	validation-rmse:4.79930
# [375]	validation-rmse:4.79931
# [376]	validation-rmse:4.79933
# [377]	validation-rmse:4.79935
# [378]	validation-rmse:4.79936
# [379]	validation-rmse:4.79936
# [380]	validation-rmse:4.79938
# [381]	validation-rmse:4.79939
# [382]	validation-rmse:4.79925
# [383]	validation-rmse:4.79915
# [384]	validation-rmse:4.79915
# [385]	validation-rmse:4.79916
# [386]	validation-rmse:4.79920
# [387]	validation-rmse:4.79914
# [388]	validation-rmse:4.79918
# [389]	validation-rmse:4.79918
# [390]	validation-rmse:4.79905
# [391]	validation-rmse:4.79909
# [392]	validation-rmse:4.79912
# [393]	validation-rmse:4.79907
# [394]	validation-rmse:4.79912
# [395]	validation-rmse:4.79911
# [396]	validation-rmse:4.79902
# [397]	validation-rmse:4.79899
# [398]	validation-rmse:4.79890
# [399]	validation-rmse:4.79889
# [400]	validation-rmse:4.79890
# [401]	validation-rmse:4.79889
# [402]	validation-rmse:4.79885
# [403]	validation-rmse:4.79888
# [404]	validation-rmse:4.79886
# [405]	validation-rmse:4.79884
# [406]	validation-rmse:4.79887
# [407]	validation-rmse:4.79889
# [408]	validation-rmse:4.79887
# [409]	validation-rmse:4.79895
# [410]	validation-rmse:4.79894
# [411]	validation-rmse:4.79896
# [412]	validation-rmse:4.79897
# [413]	validation-rmse:4.79894
# [414]	validation-rmse:4.79895
# [415]	validation-rmse:4.79894
# [416]	validation-rmse:4.79856
# [417]	validation-rmse:4.79858
# ...
# [80]	validation-rmse:5.04699
# [81]	validation-rmse:5.04658
# [82]	validation-rmse:5.04668
# [83]	validation-rmse:5.04682
# [84]	validation-rmse:5.04677
# [85]	validation-rmse:5.04659
# [86]	validation-rmse:5.04646
# [87]	validation-rmse:5.04627
# [88]	validation-rmse:5.04613
# [89]	validation-rmse:5.04588
# [90]	validation-rmse:5.04604
# [91]	validation-rmse:5.04622
# [92]	validation-rmse:5.04640
# [93]	validation-rmse:5.04631
# [94]	validation-rmse:5.04645
# [95]	validation-rmse:5.04638
# [96]	validation-rmse:5.04680
# [97]	validation-rmse:5.04665
# [98]	validation-rmse:5.04654
# [99]	validation-rmse:5.04638
# [100]	validation-rmse:5.04636
# [101]	validation-rmse:5.04633
# [102]	validation-rmse:5.04628
# [103]	validation-rmse:5.04612
# [104]	validation-rmse:5.04609
# [105]	validation-rmse:5.04612
# [106]	validation-rmse:5.04611
# [107]	validation-rmse:5.04619
# [108]	validation-rmse:5.04620
# [109]	validation-rmse:5.04615
# [110]	validation-rmse:5.04624
# [111]	validation-rmse:5.04624
# [112]	validation-rmse:5.04631
# [113]	validation-rmse:5.04631
# [114]	validation-rmse:5.04670
# [115]	validation-rmse:5.04681
# [116]	validation-rmse:5.04680
# [117]	validation-rmse:5.04691
# [118]	validation-rmse:5.04719
# [119]	validation-rmse:5.04726
# [120]	validation-rmse:5.04750
# [121]	validation-rmse:5.04833
# [122]	validation-rmse:5.04841
# [123]	validation-rmse:5.04847
# [124]	validation-rmse:5.04881
# [125]	validation-rmse:5.04917
# [126]	validation-rmse:5.04921
# [127]	validation-rmse:5.04940
# [128]	validation-rmse:5.04951
# [129]	validation-rmse:5.04967
# [130]	validation-rmse:5.05018
# [131]	validation-rmse:5.05021
# [132]	validation-rmse:5.05071
# [133]	validation-rmse:5.05082
# [134]	validation-rmse:5.05121
# [135]	validation-rmse:5.05127
# [136]	validation-rmse:5.05139
# [137]	validation-rmse:5.05169
# [138]	validation-rmse:5.05206
# [00:01:40] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:15.56540
# [1]	validation-rmse:14.76594
# [2]	validation-rmse:14.02116
# [3]	validation-rmse:13.32751
# [4]	validation-rmse:12.68185
# [5]	validation-rmse:12.08171
# [6]	validation-rmse:11.52327
# [7]	validation-rmse:11.00514
# [8]	validation-rmse:10.52430
# [9]	validation-rmse:10.07806
# [10]	validation-rmse:9.66470
# [11]	validation-rmse:9.28254
# [12]	validation-rmse:8.92932
# [13]	validation-rmse:8.60259
# [14]	validation-rmse:8.30185
# [15]	validation-rmse:8.02398
# [16]	validation-rmse:7.76844
# [17]	validation-rmse:7.53322
# [18]	validation-rmse:7.31688
# [19]	validation-rmse:7.11846
# [20]	validation-rmse:6.93616
# [21]	validation-rmse:6.76931
# [22]	validation-rmse:6.61619
# [23]	validation-rmse:6.47615
# [24]	validation-rmse:6.34830
# [25]	validation-rmse:6.23080
# [26]	validation-rmse:6.12395
# [27]	validation-rmse:6.02614
# [28]	validation-rmse:5.93701
# [29]	validation-rmse:5.85544
# [30]	validation-rmse:5.78112
# [31]	validation-rmse:5.71323
# [32]	validation-rmse:5.65110
# [33]	validation-rmse:5.59440
# [34]	validation-rmse:5.54280
# [35]	validation-rmse:5.49558
# [36]	validation-rmse:5.45221
# [37]	validation-rmse:5.41287
# [38]	validation-rmse:5.37668
# [39]	validation-rmse:5.34324
# [40]	validation-rmse:5.31292
# [41]	validation-rmse:5.28512
#  34%|███▍      | 17/50 [4:05:34<7:56:41, 866.71s/trial, best loss: 4.797837893499549]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 12
#       1 search_space = {
#       2     'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
#       3     'learning_rate': hp.loguniform('learning_rate', -3, 0),
#    (...)
#       8     'seed': 42
#       9 }
# ---> 12 best_result = fmin(
#      13     fn=objective,
#      14     space=search_space,
#      15     algo=tpe.suggest,
#      16     max_evals=50,
#      17     trials=Trials()
#      18 )
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:540, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     537     fn = __objective_fmin_wrapper(fn)
#     539 if allow_trials_fmin and hasattr(trials, "fmin"):
# --> 540     return trials.fmin(
#     541         fn,
#     542         space,
#     543         algo=algo,
#     544         max_evals=max_evals,
#     545         timeout=timeout,
#     546         loss_threshold=loss_threshold,
#     547         max_queue_len=max_queue_len,
#     548         rstate=rstate,
#     549         pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     550         verbose=verbose,
#     551         catch_eval_exceptions=catch_eval_exceptions,
#     552         return_argmin=return_argmin,
#     553         show_progressbar=show_progressbar,
#     554         early_stop_fn=early_stop_fn,
#     555         trials_save_file=trials_save_file,
#     556     )
#     558 if trials is None:
#     559     if os.path.exists(trials_save_file):
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/base.py:671, in Trials.fmin(self, fn, space, algo, max_evals, timeout, loss_threshold, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar, early_stop_fn, trials_save_file)
#     666 # -- Stop-gap implementation!
#     667 #    fmin should have been a Trials method in the first place
#     668 #    but for now it's still sitting in another file.
#     669 from .fmin import fmin
# --> 671 return fmin(
#     672     fn,
#     673     space,
#     674     algo=algo,
#     675     max_evals=max_evals,
#     676     timeout=timeout,
#     677     loss_threshold=loss_threshold,
#     678     trials=self,
#     679     rstate=rstate,
#     680     verbose=verbose,
#     681     max_queue_len=max_queue_len,
#     682     allow_trials_fmin=False,  # -- prevent recursion
#     683     pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     684     catch_eval_exceptions=catch_eval_exceptions,
#     685     return_argmin=return_argmin,
#     686     show_progressbar=show_progressbar,
#     687     early_stop_fn=early_stop_fn,
#     688     trials_save_file=trials_save_file,
#     689 )
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:586, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     583 rval.catch_eval_exceptions = catch_eval_exceptions
#     585 # next line is where the fmin is actually executed
# --> 586 rval.exhaust()
#     588 if return_argmin:
#     589     if len(trials.trials) == 0:
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:364, in FMinIter.exhaust(self)
#     362 def exhaust(self):
#     363     n_done = len(self.trials)
# --> 364     self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     365     self.trials.refresh()
#     366     return self
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:300, in FMinIter.run(self, N, block_until_done)
#     297     time.sleep(self.poll_interval_secs)
#     298 else:
#     299     # -- loop over trials and do the jobs directly
# --> 300     self.serial_evaluate()
#     302 self.trials.refresh()
#     303 if self.trials_save_file != "":
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:178, in FMinIter.serial_evaluate(self, N)
#     176 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     177 try:
# --> 178     result = self.domain.evaluate(spec, ctrl)
#     179 except Exception as e:
#     180     logger.error("job exception: %s" % str(e))
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/base.py:892, in Domain.evaluate(self, config, ctrl, attach_attachments)
#     883 else:
#     884     # -- the "work" of evaluating `config` can be written
#     885     #    either into the pyll part (self.expr)
#     886     #    or the normal Python part (self.fn)
#     887     pyll_rval = pyll.rec_eval(
#     888         self.expr,
#     889         memo=memo,
#     890         print_node_on_error=self.rec_eval_print_node_on_error,
#     891     )
# --> 892     rval = self.fn(pyll_rval)
#     894 if isinstance(rval, (float, int, np.number)):
#     895     dict_rval = {"loss": float(rval), "status": STATUS_OK}
#
# Cell In[21], line 6, in objective(params)
#       4 mlflow.set_tag("model", "xgboost")
#       5 mlflow.log_params(params)
# ----> 6 booster = xgb.train(
#       7     params=params,
#       8     dtrain=train,
#       9     num_boost_round=1000,
#      10     evals=[(valid, "validation")],
#      11     early_stopping_rounds=50
#      12 )
#      14 y_pred = booster.predict(valid)
#      15 rmse = mean_squared_error(y_val, y_pred, squared=False)
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/training.py:185, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     183 if cb_container.before_iteration(bst, i, dtrain, evals):
#     184     break
# --> 185 bst.update(dtrain, i, obj)
#     186 if cb_container.after_iteration(bst, i, dtrain, evals):
#     187     break
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:1918, in Booster.update(self, dtrain, iteration, fobj)
#    1915 self._validate_dmatrix_features(dtrain)
#    1917 if fobj is None:
# -> 1918     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1919                                             ctypes.c_int(iteration),
#    1920                                             dtrain.handle))
#    1921 else:
#    1922     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:
